# %%
# %pip install opencv-python
# %pip install ipywidgets
# %pip install ipympl
# %pip install lmfit
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.7.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (8.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (6.20.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (4.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.8.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.9.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.0.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.6)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.14.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipympl in /opt/conda/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in /opt/conda/lib/python3.10/site-packages (from ipympl) (8.9.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from ipympl) (3.6.3)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /opt/conda/lib/python3.10/site-packages (from ipympl) (8.0.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from ipympl) (1.23.5)
# Requirement already satisfied: traitlets<6 in /opt/conda/lib/python3.10/site-packages (from ipympl) (5.8.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (2.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.20.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.38.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (25.0.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (8.0.2)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (1.2.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (2.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lmfit in /opt/conda/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: asteval>=0.9.28 in /opt/conda/lib/python3.10/site-packages (from lmfit) (0.9.28)
# Requirement already satisfied: scipy>=1.6 in /opt/conda/lib/python3.10/site-packages (from lmfit) (1.10.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from lmfit) (3.1.7)
# Requirement already satisfied: numpy>=1.19 in /opt/conda/lib/python3.10/site-packages (from lmfit) (1.23.5)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from uncertainties>=3.1.4->lmfit) (0.18.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cabervideo as cv
import pandas as pd
import ipywidgets

# %%
import importlib
import cabervideo #import the module here, so that it can be reloaded.
importlib.reload(cabervideo)
# Out:
# <module 'cabervideo' from '/home/jovyan/work/Documents/capillarybreakup/cabervideo.py'>

# %%
upload = ipywidgets.FileUpload(accept='.mp4', multiple=False)
display(upload)
# Out:
# FileUpload(value=(), accept='.mp4', description='Upload')

# %%
try:
    with open(upload.value[0]['name'], 'wb') as output_file: 
        output_file.write(upload.value[0]['content']) 
except Exception as e:
    print(f'Error: failed to save uploaded video. Details: {str(e)}')
    pass
# Out:
# Error: failed to save uploaded video. Details: tuple index out of range

# %%
test_video=cv.CaberVideo('6000cp_viscosity_standard.mp4')

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets


import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
# %matplotlib ipympl
test_video.reset_mask()
bs = cv.bbox_select(test_video[100])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_video.mask=bs.mask
test_video.show_frame(100)
# Out:
# <PIL.Image.Image image mode=RGB size=683x511>

# %%
test_video.show_video_widget()
# Out:
# VBox(children=(Output(), IntSlider(value=0, description='Frame:', max=467)))

# %%
res_table=test_video.find_radius_all()

# %%
res_table
# Out:
#      frame_num  radius_pixels                       filename
# 0            0          415.0  6000cp_viscosity_standard.mp4
# 1            1          415.0  6000cp_viscosity_standard.mp4
# 2            2          415.0  6000cp_viscosity_standard.mp4
# 3            3          415.0  6000cp_viscosity_standard.mp4
# 4            4          415.0  6000cp_viscosity_standard.mp4
# ..         ...            ...                            ...
# 463        463            0.0  6000cp_viscosity_standard.mp4
# 464        464            0.0  6000cp_viscosity_standard.mp4
# 465        465            0.0  6000cp_viscosity_standard.mp4
# 466        466            0.0  6000cp_viscosity_standard.mp4
# 467        467            0.0  6000cp_viscosity_standard.mp4
#
# [468 rows x 3 columns]

# %%
# %matplotlib inline
res_table.plot()
# Out:
# <AxesSubplot: >

# %%
res_table=cv.calibrate_res_table(res_table)
res_table
# Out:
#      frame_num  radius_pixels                       filename  strike_len_s  \
# 0            0          415.0  6000cp_viscosity_standard.mp4          20.0
# 1            1          415.0  6000cp_viscosity_standard.mp4          20.0
# 2            2          415.0  6000cp_viscosity_standard.mp4          20.0
# 3            3          415.0  6000cp_viscosity_standard.mp4          20.0
# 4            4          415.0  6000cp_viscosity_standard.mp4          20.0
# ..         ...            ...                            ...           ...
# 463        463            0.0  6000cp_viscosity_standard.mp4          20.0
# 464        464            0.0  6000cp_viscosity_standard.mp4          20.0
# 465        465            0.0  6000cp_viscosity_standard.mp4          20.0
# 466        466            0.0  6000cp_viscosity_standard.mp4          20.0
# 467        467            0.0  6000cp_viscosity_standard.mp4          20.0
#
#      fps   t_s  radius_m
# 0    100  0.00  0.005485
# 1    100  0.01  0.005485
# 2    100  0.02  0.005485
# 3    100  0.03  0.005485
# 4    100  0.04  0.005485
# ..   ...   ...       ...
# 463  100  4.63  0.000000
# 464  100  4.64  0.000000
# 465  100  4.65  0.000000
# 466  100  4.66  0.000000
# 467  100  4.67  0.000000
#
# [468 rows x 7 columns]

# %%
caber_results=cv.fit_linear_caber(res_table['t_s'], 
                               res_table['radius_m'], 
                               strike_len_s=0.1, 
                               fps=100, 
                               eta_shear=6,
                               surface_tension=40e-3,
                               filename=res_table.filename.loc[0], 
                               show_plot=True)

# %%
caber_results
# Out:
# {'time_to_breakup': 2.35,
#  'Initial radius exp': 0.0024052863436123347,
#  'lmfit_result': <lmfit.model.ModelResult at 0x7f9068ee8fa0>,
#  'extensional_viscosity_pas': 47.333314955527925,
#  'trouton_ration': 7.888885825921321}
